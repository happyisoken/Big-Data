# %% [markdown]
# #### Big Data - The Data Scientist's Toolbox
#
# These are very large datasets that are being generated very rapidly. It is defined as an enormous amount of unstructured and fast moving data.
#
# ##### Three qualities attributed to Big data are:
# 1. Volume - More and more data is becoming increasingly available(size)
# 2. Velocity - Data is being generated at an astonishing rate(speed)
# 3. Variety - The data we can analyse comes in many forms.
#
# ##### Unstructured Data Types:
# - Text files and documents
# - Websites and applications
# - Sensor data
# - Images files
# - Audio files
# - Vidoe files
# - Email data
# - Social media data
#
# ##### Challenges with big data
# 1. It is big.
# 2. It is constantly changing and updating
# 3. The variety can be overwhelming
# 4. It is messy (unstructured)
#
# ##### How Big data is used in different industries
# 1. Personalization of offerings: E.g. Amazon uses big data to know their customers and offer customize solutions.
# 2. Fraud reduction: Credit card companies like visa analyze transactions to identify unusual patterns. There reduce fraud in real time.
# 3. Predictive maintenance: Companies can use use data collected about operations to predict performance issues before they happen.
#
# Big data has many more application areas accross all industries. It is estimated that leaders in big data generate an average of 12% more revenue that those who those that do not maximise their use of analytics. If a company wants their customer data to be their competitive advantage, trust is something they do not want to lose. Customers reaction to data misuse can cause them to reduece their spending with the company.
#
# ##### How big data can trigger digital transformation.
# - Use of video tracking data
# - It requires fundamental changes to their approach towards data, employees and customers and it will affect their organizational culture.
# - Digital transformation impacts every aspect of an organization. So it is handled by decision makers at top levels to ensure success.
# - The support of the CEO is crucial to the digital transformation process. As is the support of the Chief Executive Officer, Chief Data Officer and Chief Information Officer. They also require support from the executives who control Budgets, personnel decision and day-to-day priorities. Everyone must support for it to succeed.
# - It is the way to succeed now and in the future

# %% [markdown]
# #### Foundations of Big Data

# %% [markdown]
# According to Ernst and Young, Big Data refers to the dynamic, large and disparate volumes of data being created by people, tools and machines. It requires new, innovative and scalable technology to collect, host and analytically process the vast amount of data gathered in order to derive real-time business insights that relate to consumers, risk, profit, performance, productivity management, and enhanced shareholder value.
#
# ##### Elements of big data (The V's of Big Data)
# 1. Velocity - The speed at which big data accumulates or the pace at which data is growing.
#
# 2. Volume - The scale of the data or the increase in the amount of data stored.
# Drivers of volume are:
#     - the increase in data sources,
#     - higher resolution sensors,
#     - scalable infrastructure.
#
# 3. Variety - The diversity of the data. It also reflects that data comes from different sources - machines, people and processes both internal and external to organizations.
# Structured data fits neatly into rows and columns in relational databases. While unstructured data is now organized in a pre-defined way like twits, blog posts, pictures, numbers and videos.
# Drivers of variety are:
#     - Mobile technologies
#     - Social media
#     - Wearable technologies
#     - Geo technologies
#     - Video
#     - And many more.
#
# 4. Veracity - The quality and origin of data and its conformity to facts and accuracy.
# The attributes include:
#     - Consistency
#     - Completeness
#     - Integrity
#     - Ambuguity
# Drivers include:
#     - Cost
#     - Need for traceability.
#
# 5. Value - The ability and need to turn data into value. It isn't just profit. It may have medical or social profits as well as customer, employee or personal satisfaction. The main reason that people invest time to understand big data is the value derived from it.

# %% [markdown]
# #### Big Data Analytics
#
# ##### Big Data Introduction
#
# In the last 5yrs, data have grown exponentially. We create 2.5 Quintillion bytes of data Everyday. If one stores the total Global Data into discs and pile up the discs into stack, it will grow longer than that of Eiffel Tower.
#
# ##### What is Big Data?
# The 5 V's Definition of Big Data
# - Volume
# - Velocity
# - Variety
# - Value
# - Veracity
#
# ##### Big Data Growth Drivers
# Data generated every minute come from Facebook, twitter, Reddit, Instagram and Youtube.
#
# ##### Why Big Data Analytics?
# 1. Cost reduction: cost effective storage system for huge datasets.
# 2. Faster and better decision making: provide ways to analyze information quickly and make decisions
# 3. Next generation products: Automated car, healthcare etc
# 4. Improved services or products: eveluation of customer needs & satisfaction.
#
# ##### What is Big Data Analytics
# Big data analytics examines large and different types of data to uncover hidden patterns, correlations and other insights.
#
# Big Data => Analytics => Decisions
#
# ##### Stages in Big Data Analytics
# - Identifying problem
# - Designing data requirement
# - Pre-processing Data
# - Performing Analytics over data
# - Visualizing Data
#
# ##### Big Data Analytic Domains
# - Web & E-Tailing
# - Tele-communication
# - Government
# - Healthcare
# - Finance & Banking
# - Retail
#
# ##### Big Data Analytics Use cases
# 1. Big data helped Donald Trump to win against Hillary Clinton in the US election.
#     - Collect personal data from various resources like club cards, newspaper subscription, social media etc.
#     - Messages were targetted based on voter profiles using platforms such as Facebook, Snapchat, Pandora radio etc
#     - Build an algorithm that generated top cities to reach the highest concentration of persuadable voters.
#
# 2. Walmart boosted its sales by leveraging the power of Big Data.
#     - While forecasting the demand for emergency supplies for approaching Hurricane Sandy, they gain some amazing insights.
#     - Extra supplies of strawberry Pop Tarts were dispatched to stores in Hurricane Sandy's path in 2012 and sold extremely well.
#     - Along with flashlights and emergency equipment, they found an upsurge in sales of strawberry Pop Tarts.
# 3. Apixio uses Big Data analytics to improve healthcare decision.
#     - 80% of medical and clinical information about patients is in unstructured format, such as written physician notes.
#     - Analysis of medical data using variety of different methodologies & algorithms that are machine learning based and have NLP capabilities.
#     - The patient data model generated is aggregated across population to derive larger insights like disease prevalence, treatment patterns, etc.
#
# ##### Big Data Analytical Tools
# 1. Hadoop: provides a scalable solution to store and process huge datasets in parallel and distributed fashion.
# 2. Apache Hive: is a data warehousing tool that allows us to perform big data analytics using Hive Query Language which is very similar to SQL.
# 3. Apache Pig: is a platform used to analyze large datasets representing them as data flows.
# 4. Apache Spark: is an in-memory data procesing engine that allows us to efficiently execute streaming, machine learning or SQL workloads and requires fast iterative access to datasets.
# 5. Apache HBase: is a NoSQL database that allows us to store unstructured and semi-structured data with ease and provides real time read/write acces.
#
# ##### Big Data Analytical Courses at Edureka
# - Spark and Hadoop Developer
# - Hadoop Admin
# - Data Analyst
# - Data Engineer
# - Data Scientist
#
# ##### Hadoop Case Study - Orbitz Worldwide
# Challenges:
# - Current data infrastructure is not capable of storing and processing the data generated by users everyday.
# - Enhancing current infrastructure was very expensive and has limited scalability capabilities.
# Requirements:
# - Efficient and long term storage system that can store any kind of data.
# - Analytical tool for making important business decision.
# - Cost Effective
# Solution: Apache Hadoop
# - Open Source framework that used to store and process huge datasets.
# - Easily scalable as per the need.
# - Comes with various analytical tools.
# Accomplishment with Hadoop:
# - Comparison of performance of previous methodology to Hadoop implementation
#     - Months worth of data is archived easily
#     - Earlier process took 109m 14s for extracting and processing logs whereas MapReduce process took 25m 58s only.
# - Allow them to easily derive various metrics for analytics which was a tedious task earlier.
